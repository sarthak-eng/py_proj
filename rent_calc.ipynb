# %%
#input we need from user
rent=int(input("enter your flat rent="))
food=int(input("enter your food order="))
electricity=int(input("enter your electricity unit="))
charge_per_unit=int(input("enter your charge per unit="))


persons=int(input("enter your no of persons="))
total_rent=rent*persons
total_food=food*persons
total_electricity=electricity*charge_per_unit
total_amount=total_rent+total_food+total_electricity
output=total_amount/persons
print("total rent=",total_rent)
print("total food=",total_food)
print("total electricity=",total_electricity)
print("total amount=",total_amount)
print("each person will pay=",output)
# Out:
# enter your flat rent=100000
# enter your food order=1000
# enter your electricity unit=1200
# enter your charge per unit=200
# enter your no of persons=3
# total rent= 300000
# total food= 3000
# total electricity= 240000
# total amount= 543000
# each person will pay= 181000.0

# %%
#total rent

# %%
#total food order for snaking

# %%
#elictricity unit spend

# %%
#charge per unit
charge = 0.1

# %%
#output
output=

# %%
#total amount you have to pay
